# %% [markdown]
# # Load libraries

# %%
# %matplotlib inline

import os
import math

import configparser

import numpy as np
import pandas as pd
import matplotlib.pylab as plt

import sys
sys.path.append('../..')

from scripps.utils import read_datasets, norm1d, bayesian_linear_regression

import seaborn as sns

# %%
include_NER = False

# %%
CF = read_datasets.get_configuration()
cs_annotator_names = [key for key in dict(CF.items('m2c_citizen_disease')).keys() if key not in ['path', 'm2c6_1st']]
cs_annotator_names.sort()
annotator_names = cs_annotator_names 
if include_NER:
    annotator_names = annotator_names + ['NER_expert']

# %%
all_labels = ['Disease', 'Phenotype', 'Both', 'None']

# %% [markdown]
# # Load "expert" annotations

# %%
def read_expert_disease_annotations():
    annotations = pd.DataFrame()
    anno = read_datasets.load_dataset('m2c_expert_disease', 'file')
    anno = anno[[0, 2]]
    anno[2].replace(['I-Disease', 'O', 'B-Disease', 'U-Disease', 'L-Disease'], [1, 0, 1, 1, 1], inplace=True)
    annotations = pd.concat([annotations, anno[0].rename('Token')], axis=1)
    annotations = pd.concat([annotations, anno[2].rename('NER_expert')], axis=1)
    return annotations

def read_expert_phenotype_annotations():
    annotations = pd.DataFrame()
    anno = read_datasets.load_dataset('m2c_expert_phenotype', 'file')
    anno = anno[[0, 2]]
    anno[2].replace(['I-phenotype', 'O', 'B-phenotype', 'L-phenotype', 'U-phenotype'], [1, 0, 1, 1, 1], inplace=True)
    annotations = pd.concat([annotations, anno[0].rename('Token')], axis=1)
    annotations = pd.concat([annotations, anno[2].rename('NER_expert')], axis=1)
    return annotations

def read_expert_mixed_annotations(disease_annotations, phenotype_annotations):
    mixed = [disease_annotations['NER_expert'] == 1][0].replace([True, False], [1, 0]) + \
    [phenotype_annotations['NER_expert'] == 1][0].replace([True, False], [2, 0])
    mixed_annotations = pd.DataFrame()
    mixed_annotations = pd.concat([mixed_annotations, disease_annotations['Token']], axis=1)
    #mixed_annotations = pd.concat([mixed_annotations, mixed.replace([0, 1, 2, 3], ['O', 'I-Disease', 'I-Phenotype', 'I-Disease_Pheno'])], axis=1)
    mixed_annotations = pd.concat([mixed_annotations, mixed.replace([0, 1, 2, 3], ['None', 'Disease', 'Phenotype', 'Both'])], axis=1)
    return mixed_annotations

# %%
expert_disease_annotations = read_expert_disease_annotations()
expert_phenotype_annotations = read_expert_phenotype_annotations()
expert_annotations = read_expert_mixed_annotations(expert_disease_annotations, expert_phenotype_annotations)

# %% [markdown]
# # Load all mark2cure citizen scientist annotations

# %%
CF = read_datasets.get_configuration()

def read_disease_annotations():
    annotations = pd.DataFrame()
    idx = 0
    for anno_name in cs_annotator_names:
        anno = read_datasets.load_dataset('m2c_citizen_disease', anno_name)
        anno[3].replace(['I-Disease', 'O'], [1, 0], inplace=True)
        if idx == 0:
            annotations = pd.concat([annotations, anno[0].rename('Token')], axis=1)
            idx += 1
        annotations = pd.concat([annotations, anno[3].rename(anno_name)], axis=1)
    return annotations

def read_phenotype_annotations():
    annotations = pd.DataFrame()
    idx = 0
    for anno_name in cs_annotator_names:
        anno = read_datasets.load_dataset('m2c_citizen_phenotype', anno_name)
        anno[3].replace(['I-Phenotype', 'O'], [1, 0], inplace=True)
        if idx == 0:
            annotations = pd.concat([annotations, anno[0].rename('Token')], axis=1)
            idx += 1
        annotations = pd.concat([annotations, anno[3].rename(anno_name)], axis=1)
    return annotations

# %% [markdown]
# # Load original annotations

# %%
def read_both_annotations():
    annotations = pd.DataFrame()
    idx = 0
    for anno_name in cs_annotator_names:
        anno = read_datasets.load_dataset('m2c', anno_name)
        anno[3].replace(['I-?', 'I-Disease_Phen', 'I-Gene'], ['O', 'I-Disease_Pheno', 'O'], inplace=True)
        anno[3].replace(['I-Disease', 'I-Phenotype', 'I-Disease_Pheno', 'O'], \
                        ['Disease', 'Phenotype', 'Both', 'None'], inplace=True)
        if idx == 0:
            annotations = pd.concat([annotations, anno[0].rename('Token')], axis=1)
            idx += 1
        annotations = pd.concat([annotations, anno[3].rename(anno_name)], axis=1)
    return annotations

def sanity_check(annotations, columns, values):
    for col in columns:
        assert set(annotations[col].unique()) == set(values)

# %%
disease_annotations = read_disease_annotations()
phenotype_annotations = read_phenotype_annotations()

# %%
mixed_annotations = read_both_annotations()
sanity_check(mixed_annotations, cs_annotator_names, all_labels)

# %%
if include_NER:
    mixed_annotations = pd.concat([mixed_annotations, expert_annotations['NER_expert']], axis=1)
    disease_annotations = pd.concat([disease_annotations, expert_disease_annotations['NER_expert']], axis=1)
    phenotype_annotations = pd.concat([phenotype_annotations, expert_phenotype_annotations['NER_expert']], axis=1)

# %%
mixed_annotations
# Out:
#               Token       m2c1       m2c2     m2c3       m2c5   m2c6_2nd
# 0        Haematuria  Phenotype  Phenotype     Both  Phenotype       Both
# 1               and       None       None     None       None       None
# 2         abdominal    Disease    Disease  Disease       Both    Disease
# 3            aortic    Disease    Disease  Disease       Both    Disease
# 4          aneurysm    Disease    Disease  Disease       Both    Disease
# 5                 .       None       None     None       None       None
# 6        Haematuria  Phenotype  Phenotype     Both  Phenotype       Both
# 7               and       None       None     None       None       None
# 8              left  Phenotype  Phenotype     None       None  Phenotype
# 9              loin  Phenotype  Phenotype     None  Phenotype  Phenotype
# 10             pain  Phenotype  Phenotype     Both  Phenotype  Phenotype
# 11               in       None       None     None       None       None
# 12                a       None       None     None       None       None
# 13          patient       None       None     None       None       None
# 14             with       None       None     None       None       None
# 15        abdominal    Disease    Disease  Disease       Both    Disease
# 16           aortic    Disease    Disease  Disease       Both    Disease
# 17         aneurysm       None    Disease  Disease       Both    Disease
# 18              and       None       None     None       None       None
# 19       associated       None       None     None       None       None
# 20             with       None       None     None       None       None
# 21              the       None       None     None       None       None
# 22     radiological       None       None     None       None       None
# 23          finding       None       None     None       None       None
# 24               of       None       None     None       None       None
# 25                a       None       None     None       None       None
# 26           poorly       None       None     None  Phenotype  Phenotype
# 27               or       None       None     None  Phenotype  Phenotype
# 28              non       None       None     None  Phenotype  Phenotype
# 29                -       None       None     None  Phenotype  Phenotype
# ...             ...        ...        ...      ...        ...        ...
# 7833              ,       None       None     None       None       None
# 7834              2       None       None     None       None       None
# 7835              -       None       None     None       None       None
# 7836  methylbutanal       None       None     None       None       None
# 7837              ,       None       None     None       None       None
# 7838              2       None       None     None       None       None
# 7839              -       None       None     None       None       None
# 7840         acetyl       None       None     None       None       None
# 7841              -       None       None     None       None       None
# 7842              1       None       None     None       None       None
# 7843              -       None       None     None       None       None
# 7844      pyrroline       None       None     None       None       None
# 7845              ,       None       None     None       None       None
# 7846              1       None       None     None       None       None
# 7847              -       None       None     None       None       None
# 7848          octen       None       None     None       None       None
# 7849              -       None       None     None       None       None
# 7850              3       None       None     None       None       None
# 7851              -       None       None     None       None       None
# 7852             ol       None       None     None       None       None
# 7853              ,       None       None     None       None       None
# 7854            and       None       None     None       None       None
# 7855              1       None       None     None       None       None
# 7856              -       None       None     None       None       None
# 7857          octen       None       None     None       None       None
# 7858              -       None       None     None       None       None
# 7859              3       None       None     None       None       None
# 7860              -       None       None     None       None       None
# 7861            one       None       None     None       None       None
# 7862              .       None       None     None       None       None
#
# [7863 rows x 6 columns]

# %% [markdown]
# # Load GLAD results

# %%
def load_glad_results(dataset):
    glad_results = read_datasets.load_glad_results(dataset)
    glad_results.rename(columns={0:'Token', 1:'Not Relevant', 2:'Relevant'}, inplace=True)
    glad_results['Token'] = glad_results['Token'].str.split("_").apply(lambda x:x[0])
    glad_results['Relevant'] = glad_results['Relevant'].astype('float')
    glad_results['Not Relevant'] = glad_results['Not Relevant'].astype('float')
    return glad_results

# %%
glad_disease = load_glad_results('disease')
glad_phenotype = load_glad_results('phenotype')
glad_combined = load_glad_results('combined')

# %%
#glad_phenotype[glad_phenotype['Relevant'] > 0.5]
glad_combined[glad_combined['Relevant'] > 0.5]
# Out:
#                     Token  Not Relevant  Relevant
# 0              haematuria       0.00000   1.00000
# 2               abdominal       0.00000   1.00000
# 3                  aortic       0.00000   1.00000
# 4                aneurysm       0.00000   1.00000
# 6              haematuria       0.00000   1.00000
# 8                    left       0.27792   0.72208
# 9                    loin       0.00365   0.99635
# 10                   pain       0.00000   1.00000
# 15              abdominal       0.00000   1.00000
# 16                 aortic       0.00000   1.00000
# 17               aneurysm       0.00914   0.99086
# 38                  aorto       0.00914   0.99086
# 39                      -       0.00914   0.99086
# 40                   left       0.00914   0.99086
# 41                  renal       0.00914   0.99086
# 42                   vein       0.00914   0.99086
# 43                fistula       0.00914   0.99086
# 50               aneurysm       0.00914   0.99086
# 62             acanthosis       0.00000   1.00000
# 63              nigricans       0.00000   1.00000
# 65             acanthosis       0.00000   1.00000
# 66              nigricans       0.00000   1.00000
# 72         hyperpigmented       0.28324   0.71676
# 73                   skin       0.28324   0.71676
# 79              endocrine       0.29778   0.70222
# 80              disorders       0.29778   0.70222
# 82           malignancies       0.29778   0.70222
# 93              fractured       0.00000   1.00000
# 94              phalanges       0.00000   1.00000
# 105             fractured       0.00000   1.00000
# ...                   ...           ...       ...
# 6785            tenseness       0.00390   0.99610
# 6844  pseudohallucination       0.29778   0.70222
# 7051                focal       0.00390   0.99610
# 7052         neurological       0.00000   1.00000
# 7053              deficit       0.00000   1.00000
# 7055          sarcoidosis       0.00000   1.00000
# 7057          sarcoidosis       0.00000   1.00000
# 7062               stroke       0.00000   1.00000
# 7064                focal       0.00000   1.00000
# 7065         neurological       0.00000   1.00000
# 7066              deficit       0.00000   1.00000
# 7069                focal       0.00000   1.00000
# 7070         neurological       0.00000   1.00000
# 7071              deficit       0.00000   1.00000
# 7084             episodic       0.00365   0.99635
# 7085                  non       0.00365   0.99635
# 7086                    -       0.00365   0.99635
# 7087               fluent       0.00365   0.99635
# 7088            dysphasia       0.00000   1.00000
# 7102              seizure       0.00000   1.00000
# 7116     neurosarcoidosis       0.00000   1.00000
# 7121            ischaemic       0.00000   1.00000
# 7122         neurological       0.00000   1.00000
# 7123              deficit       0.00000   1.00000
# 7205              fatigue       0.09503   0.90497
# 7406           insulinoma       0.00000   1.00000
# 7611            posterior       0.00365   0.99635
# 7612             urethral       0.00000   1.00000
# 7613           strictures       0.00000   1.00000
# 7709                   ms       0.00000   1.00000
#
# [812 rows x 3 columns]

# %%
mixed_annotations.loc[263]
# Out:
# Token       Scanning
# m2c1            None
# m2c2            None
# m2c3            None
# m2c5            None
# m2c6_2nd        None
# Name: 263, dtype: object

# %% [markdown]
# # Filter relevant rows

# %%
'''
def get_relevant_rows(annotations, disease_thresh=0.5, pheno_thresh=0.5):
    #relevant = annotations[annotator_names] != 'None'
    #relevant = annotations[relevant.all(axis=1)]
    
    #relevant = annotations[~(annotations[annotator_names] == 'None').all(axis=1)]
    relevant = annotations[(glad_phenotype['Relevant'] > pheno_thresh) | (glad_disease['Relevant'] > disease_thresh)]
    return relevant
'''
def get_relevant_rows(annotations, thresh=0.5):
    #relevant = annotations[annotator_names] != 'None'
    #relevant = annotations[relevant.all(axis=1)]
    
    #relevant = annotations[~(annotations[annotator_names] == 'None').all(axis=1)]
    relevant = annotations[glad_combined['Relevant'] > thresh]
    return relevant
#'''

# %%
relevant_annotations = get_relevant_rows(mixed_annotations)

# %%
len(relevant_annotations)
# Out:
# 812

# %%
disease_annotations = disease_annotations.iloc[relevant_annotations.index]
phenotype_annotations = phenotype_annotations.iloc[relevant_annotations.index]

# %%
#disease_annotations = disease_annotations.reset_index()
#phenotype_annotations = phenotype_annotations.reset_index()
relevant_annotations = relevant_annotations.reset_index()
no_nones = {}
nones = {}
for annotator_name in annotator_names:
    no_nones[annotator_name] = relevant_annotations[relevant_annotations[annotator_name] != 'None'].index
    nones[annotator_name] = relevant_annotations[relevant_annotations[annotator_name] == 'None'].index

# %%
token_nones = {}
token_no_nones = {}
for k in range(len(relevant_annotations)):
    l = relevant_annotations.loc[k][relevant_annotations.loc[k] != 'None'].index
    token_no_nones[k] = [annotator_names.index(zx) for zx in l if zx in annotator_names]
    l = relevant_annotations.loc[k][relevant_annotations.loc[k] == 'None'].index
    token_nones[k] = [annotator_names.index(zx) for zx in l if zx in annotator_names]

# %% [markdown]
# # Initialize latent variables

# %%
K = disease_annotations.shape[0]
J = disease_annotations.shape[1] - 1

latent = {}

latent['theta'] = np.zeros(K)
latent['d_alpha'] = np.zeros(J)
latent['d_beta'] = np.zeros(J)
latent['d_z'] = np.zeros((K, J))

latent['p_alpha'] = np.zeros(J)
latent['p_beta'] = np.zeros(J)
latent['p_z'] = np.zeros((K, J))

#Should these be separate for disease and phenotype?
latent['b0'] = np.zeros(2)
latent['B0_scale'] = 1
latent['m0'] = np.zeros(K) #TODO: ask HS regarding changing certain values here.
latent['C0_scale'] = 1

latent['K'] = K
latent['J'] = J

# %% [markdown]
# # Define functions for resampling using Gibbs sampling

# %%
def __get_alpha_beta_z(mode):
    if mode == 'disease':
        alpha = latent['d_alpha']
        beta = latent['d_beta']
        z = latent['d_z']
    else:
        alpha = latent['p_alpha']
        beta = latent['p_beta']
        z = latent['p_z']
    return alpha, beta, z

# %%
def __resample_z(alpha, beta, z, annotations):
    interval = [-100, 100] #Should this be changed?
    for k in range(K):
    #for k in annotations.index:
        for j in range(J):
            mean = alpha[j] + beta[j]*latent['theta'][k]
            std_dev = 1
            #if relevant_annotations[annotator_names[j]][relevant_annotations.index[k]] == 'None':
            #    continue
            if k in nones[annotator_names[j]]:
                continue
            if(annotations[annotator_names[j]][annotations.index[k]] == 0):
                z[k, j] = norm1d.truncnormal(mean, std_dev, interval[0], 0)
            elif(annotations[annotator_names[j]][annotations.index[k]] == 1):
                z[k, j] = norm1d.truncnormal(mean, std_dev, 0, interval[1])
    
def resample_z(mode):
    alpha, beta, z = __get_alpha_beta_z(mode)
    if mode == 'disease':
        annotations = disease_annotations
    else:
        annotations = phenotype_annotations
    __resample_z(alpha, beta, z, annotations)

# %%
def __resample_alpha_beta(alpha, beta, z):
    for j in range(J):
        
        Y = z[no_nones[annotator_names[j]], j]
        X = np.vstack((np.ones(len(no_nones[annotator_names[j]])), latent['theta'][no_nones[annotator_names[j]]])).T
        
        #Y = z[:, j]
        #X = np.vstack((np.ones(K), latent['theta'])).T
        
        WN, VN = bayesian_linear_regression.linreg_post(X, Y, latent['b0'], latent['B0_scale'], 1)
        sample = np.random.multivariate_normal(WN, VN)
        alpha[j] = sample[0]
        beta[j] = sample[1]

def resample_alpha_beta(mode):
    alpha, beta, z = __get_alpha_beta_z(mode)
    __resample_alpha_beta(alpha, beta, z)

# %%
def resample_theta():
    for k in range(K):
        #Y = latent['d_z'][k, :] - latent['d_alpha'] + latent['p_z'][k, :] - latent['p_alpha']
        #X = latent['d_beta'] + latent['p_beta']
        '''
        a = []
        for j in range(len(annotator_names)):
            if k in no_nones[annotator_names[j]]:
                a.append(j)
        '''
        a = token_no_nones[k]
        #a = relevant_annotations.loc[k][annotator_names] != 'None'
        #a = [a.index.get_loc(ind) for ind in a.index[a == True]]
        a = np.array(a)
        
        latent['d_z'][k, a]
        latent['d_alpha'][a]
        latent['p_z'][k, a]
        latent['p_alpha'][a]
        
        Y = np.concatenate((latent['d_z'][k, a] - latent['d_alpha'][a], latent['p_z'][k, a] - latent['p_alpha'][a]), axis=0)
        X = np.concatenate((latent['d_beta'][a], latent['p_beta'][a]), axis=0)
        
        #Y = np.concatenate(((latent['d_z'][k, :] - latent['d_alpha']), (latent['p_z'][k, :] - latent['p_alpha'])), axis=0)
        #X = np.concatenate((latent['d_beta'], latent['p_beta']), axis=0)
        X = np.reshape(X, (-1, 1))
        WN, VN = bayesian_linear_regression.linreg_post(X, Y, latent['m0'][k], latent['C0_scale'], 1)
        latent['theta'][k] = np.random.normal(WN, math.sqrt(VN))

# %%
def save_latent_variables():
    #TODO: save to csv.
    pass


def resample():
    resample_z('disease')
    resample_z('phenotype')
    resample_theta()
    resample_alpha_beta('disease')
    resample_alpha_beta('phenotype')
    
    save_latent_variables()
    
def has_converged():
    #TODO
    pass
    
def run_sampling(num_iter, thresh, print_freq=50):
    thetas = []
    d_alphas = []
    d_betas = []
    p_alphas = []
    p_betas = []
    for it in xrange(1, num_iter+1):
        resample()
        if it%print_freq == 0:
            print 'Iter {}/{} done.'.format(it, num_iter)
        if has_converged():
            break
        if it > thresh:
            thetas.append(np.array(latent['theta']))
            d_alphas.append(np.array(latent['d_alpha']))
            p_alphas.append(np.array(latent['p_alpha']))
            d_betas.append(np.array(latent['d_beta']))
            p_betas.append(np.array(latent['p_beta']))

    all_values = {}
    all_values['thetas'] = thetas
    all_values['d_alphas'] = d_alphas
    all_values['d_betas'] = d_betas
    all_values['p_alphas'] = p_alphas
    all_values['p_betas'] = p_betas
    
    return all_values

def get_averages(all_values, num_iter, thresh):
    avg_values = {}
    avg_values['theta'] = np.sum(all_values['thetas'], axis=0)/(num_iter - thresh)
    avg_values['d_alpha'] = np.sum(all_values['d_alphas'], axis=0)/(num_iter - thresh)
    avg_values['d_beta'] = np.sum(all_values['d_betas'], axis=0)/(num_iter - thresh)
    avg_values['p_alpha'] = np.sum(all_values['p_alphas'], axis=0)/(num_iter - thresh)
    avg_values['p_beta'] = np.sum(all_values['p_betas'], axis=0)/(num_iter - thresh)
    return avg_values

# %%
np.random.seed(23)
num_iter = 2000
thresh = 300
all_values = run_sampling(num_iter, thresh)
avg_values = get_averages(all_values, num_iter, thresh)
# Out:
# Iter 50/2000 done.
# Iter 100/2000 done.
# Iter 150/2000 done.
# Iter 200/2000 done.
# Iter 250/2000 done.
# Iter 300/2000 done.
# Iter 350/2000 done.
# Iter 400/2000 done.
# Iter 450/2000 done.
# Iter 500/2000 done.
# Iter 550/2000 done.
# Iter 600/2000 done.
# Iter 650/2000 done.
# Iter 700/2000 done.
# Iter 750/2000 done.
# Iter 800/2000 done.
# Iter 850/2000 done.
# Iter 900/2000 done.
# Iter 950/2000 done.
# Iter 1000/2000 done.
# Iter 1050/2000 done.
# Iter 1100/2000 done.
# Iter 1150/2000 done.
# Iter 1200/2000 done.
# Iter 1250/2000 done.
# Iter 1300/2000 done.
# Iter 1350/2000 done.
# Iter 1400/2000 done.
# Iter 1450/2000 done.
# Iter 1500/2000 done.
# Iter 1550/2000 done.
# Iter 1600/2000 done.
# Iter 1650/2000 done.
# Iter 1700/2000 done.
# Iter 1750/2000 done.
# Iter 1800/2000 done.
# Iter 1850/2000 done.
# Iter 1900/2000 done.
# Iter 1950/2000 done.
# Iter 2000/2000 done.

# %%
def get_annotator_bias(alpha, beta):
    # compute xr and xa using above latent vars.
    xa = -(4*alpha - beta*beta)/(4*beta)
    xr = -(4*alpha + beta*beta)/(4*beta)
    return xa, xr

def plot_thetas(pos_annos, annotator):
    pos_annos['zeros'] = 0
    ax = sns.scatterplot(x="theta", y="zeros", hue=annotator, \
                         data=pos_annos, hue_order=['I-Disease', 'I-Disease_Pheno', 'I-Phenotype'])

# %%
theta_min = min(avg_values['theta'])
theta_max = max(avg_values['theta'])
print 'theta range: ({}, {})'.format(theta_min, theta_max)
# Out:
# theta range: (-1.38029725729, 2.06805970508)

# %%
relevant_annotations = relevant_annotations.reset_index()

# %%
pos = pd.DataFrame()
pos = pd.concat([pos, relevant_annotations[['Token'] + annotator_names]])
pos = pd.concat([pos, pd.Series(avg_values['theta']).rename('theta')], axis=1)
pos
# Out:
#                    Token       m2c1       m2c2       m2c3       m2c5  \
# 0             Haematuria  Phenotype  Phenotype       Both  Phenotype
# 1              abdominal    Disease    Disease    Disease       Both
# 2                 aortic    Disease    Disease    Disease       Both
# 3               aneurysm    Disease    Disease    Disease       Both
# 4             Haematuria  Phenotype  Phenotype       Both  Phenotype
# 5                   left  Phenotype  Phenotype       None       None
# 6                   loin  Phenotype  Phenotype       None  Phenotype
# 7                   pain  Phenotype  Phenotype       Both  Phenotype
# 8              abdominal    Disease    Disease    Disease       Both
# 9                 aortic    Disease    Disease    Disease       Both
# 10              aneurysm       None    Disease    Disease       Both
# 11                 aorto       None    Disease    Disease    Disease
# 12                     -       None    Disease    Disease    Disease
# 13                  left       None    Disease    Disease    Disease
# 14                 renal       None    Disease    Disease    Disease
# 15                  vein       None    Disease    Disease    Disease
# 16               fistula       None       Both       Both    Disease
# 17              aneurysm       None       Both    Disease       Both
# 18            Acanthosis    Disease       Both       Both       Both
# 19             nigricans    Disease       Both       Both       Both
# 20            Acanthosis    Disease       Both       Both       Both
# 21             nigricans    Disease       Both       Both       Both
# 22        hyperpigmented  Phenotype       None  Phenotype       None
# 23                  skin  Phenotype       None  Phenotype       None
# 24             endocrine    Disease       None       None       Both
# 25             disorders    Disease       None       None       Both
# 26          malignancies    Disease       None       None       Both
# 27             fractured    Disease  Phenotype  Phenotype    Disease
# 28             phalanges    Disease  Phenotype  Phenotype    Disease
# 29             fractured    Disease  Phenotype  Phenotype    Disease
# ..                   ...        ...        ...        ...        ...
# 782            tenseness  Phenotype       None  Phenotype  Phenotype
# 783  pseudohallucination    Disease       None       None  Phenotype
# 784                focal       Both       None       Both  Phenotype
# 785         neurological       Both  Phenotype       Both  Phenotype
# 786              deficit       Both  Phenotype       Both  Phenotype
# 787          sarcoidosis    Disease    Disease    Disease       Both
# 788          Sarcoidosis    Disease    Disease    Disease       Both
# 789               stroke    Disease    Disease    Disease  Phenotype
# 790                focal       Both  Phenotype       Both  Phenotype
# 791         neurological       Both  Phenotype       Both  Phenotype
# 792              deficit       Both  Phenotype       Both  Phenotype
# 793                focal       Both  Phenotype       Both  Phenotype
# 794         neurological       Both  Phenotype       Both  Phenotype
# 795              deficit       Both  Phenotype       Both  Phenotype
# 796             episodic  Phenotype  Phenotype       None  Phenotype
# 797                  non  Phenotype  Phenotype       None  Phenotype
# 798                    -  Phenotype  Phenotype       None  Phenotype
# 799               fluent  Phenotype  Phenotype       None  Phenotype
# 800            dysphasia       Both  Phenotype       Both  Phenotype
# 801              seizure    Disease       Both       Both  Phenotype
# 802     neurosarcoidosis    Disease    Disease    Disease       Both
# 803            ischaemic       Both       Both  Phenotype  Phenotype
# 804         neurological       Both       Both  Phenotype  Phenotype
# 805              deficit       Both       Both  Phenotype  Phenotype
# 806              fatigue  Phenotype       None  Phenotype  Phenotype
# 807           insulinoma       Both    Disease       Both  Phenotype
# 808            posterior    Disease    Disease       None    Disease
# 809             urethral    Disease    Disease       Both    Disease
# 810           strictures    Disease    Disease       Both    Disease
# 811                   MS    Disease    Disease    Disease    Disease
#
#       m2c6_2nd     theta
# 0         Both  1.201779
# 1      Disease -0.482135
# 2      Disease -0.454420
# 3      Disease -0.429371
# 4         Both  1.219414
# 5    Phenotype  1.857872
# 6    Phenotype  1.922677
# 7    Phenotype  1.396721
# 8      Disease -0.443896
# 9      Disease -0.434968
# 10     Disease -0.436164
# 11     Disease -1.030184
# 12     Disease -1.005206
# 13     Disease -1.148942
# 14     Disease -1.172711
# 15     Disease -1.068951
# 16     Disease  0.118213
# 17     Disease  0.117341
# 18     Disease  0.178343
# 19     Disease  0.176246
# 20     Disease  0.200392
# 21     Disease  0.198073
# 22   Phenotype  1.989046
# 23   Phenotype  1.905903
# 24     Disease -0.291159
# 25     Disease -0.291181
# 26     Disease -0.320879
# 27     Disease  0.450410
# 28     Disease  0.457387
# 29     Disease  0.452268
# ..         ...       ...
# 782  Phenotype  1.921041
# 783  Phenotype  0.790939
# 784    Disease  0.646008
# 785    Disease  0.834107
# 786    Disease  0.839292
# 787    Disease -0.454409
# 788    Disease -0.459153
# 789    Disease -0.022613
# 790    Disease  0.832939
# 791    Disease  0.826986
# 792    Disease  0.858268
# 793    Disease  0.860384
# 794    Disease  0.831964
# 795    Disease  0.810552
# 796  Phenotype  1.865329
# 797  Phenotype  1.838620
# 798  Phenotype  1.975713
# 799  Phenotype  1.781728
# 800    Disease  0.854583
# 801    Disease  0.364885
# 802    Disease -0.497607
# 803    Disease  0.588642
# 804    Disease  0.584779
# 805    Disease  0.582968
# 806       None  1.596515
# 807    Disease  0.284534
# 808    Disease -1.055087
# 809    Disease -0.392246
# 810    Disease -0.398161
# 811    Disease -1.093425
#
# [812 rows x 7 columns]

# %%
def plot_thetas(pos_annos, annotator):
    pos_annos['zeros'] = 0
    #pos_annos = pos_annos[pos_annos[annotator] == 'Phenotype']
    pos_annos = pos_annos[pos_annos[annotator] != 'None']
    ax = sns.scatterplot(x="theta", y="zeros", hue=annotator, data=pos_annos, \
                         hue_order=['Disease', 'Both', 'Phenotype'], \
                         palette={'Disease':'green', 'Phenotype':'red', 'Both':'blue'}, s=75)
    ax.get_yaxis().set_visible(False)
    ax.set_title(annotator + ' labels')
    ax.arrow(-2.6, 0, 7.1, 0, head_width=0.00006, head_length=0.00002, width=0.000002, fc='brown', ec='brown') 
    ax.set_xlabel('Disease-Phenotype spectrum')
    return ax
    #ax.set(xticks=[-2.0, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0, 2.5])

# %%
a4_dims = (20, 13)
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=a4_dims)

idx = 0
for idx in range(5):
    ax = fig.add_subplot(2, 3, idx+1)
    ax = plot_thetas(pos, annotator_names[idx])
    idx += 1
    
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec


def format_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        ax.tick_params(labelbottom=False, labelleft=False)

# %%
ax = plot_thetas(pos, annotator_names[0])

# %%
plot_thetas(pos, annotator_names[1])

# %%
plot_thetas(pos, annotator_names[2])

# %%
plot_thetas(pos, annotator_names[3])

# %%
plot_thetas(pos, annotator_names[4])

# %%
xda, xdr = get_annotator_bias(avg_values['d_alpha'], avg_values['d_beta'])

# %%
xpa, xpr = get_annotator_bias(avg_values['p_alpha'], avg_values['p_beta'])

# %%
xda - xdr
# Out:
# array([-0.7207706 , -1.97356738, -0.69600375, -1.23331695, -0.44838699])

# %%
xpa - xpr
# Out:
# array([0.82784406, 1.49354308, 0.8592023 , 0.79599017, 0.5966023 ])

# %%
(xda + xdr)/2
# Out:
# array([1.10370016, 0.51793982, 0.84593994, 0.31319994, 1.6693482 ])

# %%
(xpa + xpr)/2
# Out:
# array([ 0.45307719,  0.35533866,  0.09670889, -0.39938302,  1.23528939])

# %%
loc_pd = pd.DataFrame()
loc_pd['xda'] = xda
loc_pd['xdr'] = xdr
loc_pd['xpa'] = xpa
loc_pd['xpr'] = xpr
loc_pd['annotator'] = annotator_names

# %%
loc_pd
# Out:
#         xda       xdr       xpa       xpr annotator
# 0  0.743315  1.464085  0.866999  0.039155      m2c1
# 1 -0.468844  1.504724  1.102110 -0.391433      m2c2
# 2  0.497938  1.193942  0.526310 -0.332892      m2c3
# 3 -0.303459  0.929858 -0.001388 -0.797378      m2c5
# 4  1.445155  1.893542  1.533591  0.936988  m2c6_2nd

# %%
dis_pd = pd.DataFrame()
dis_pd['xda'] = xda
dis_pd['xdr'] = xdr
dis_pd['annotator'] = annotator_names

phe_pd = pd.DataFrame()
phe_pd['xpa'] = xpa
phe_pd['xpr'] = xpr
phe_pd['annotator'] = annotator_names
#'''

sns.set(style="whitegrid")

dis_pd = pd.melt(dis_pd, "annotator", var_name="measurement")
phe_pd = pd.melt(phe_pd, "annotator", var_name="measurement")

#print(dis_pd)
#print
#print(phe_pd)

f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=dis_pd, dodge=0, join=False,
              markers="o", scale=1, ci=None, palette=sns.xkcd_palette(["green", "light green"]))

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=phe_pd, dodge=0, join=False,
              markers="x", scale=1, ci=None, palette=sns.xkcd_palette(["dark red", "light red"]))

#ax.set_title('Annotator positions')
ax.set_xlabel('Annotator position on the spectrum')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
dis_loc = (xda + xdr)/2
phe_loc = (xpa + xpr)/2

phe_loc - dis_loc
# Out:
# array([-0.65062297, -0.16260116, -0.74923105, -0.71258297, -0.43405881])

# %%
dis_phe_pd = pd.DataFrame()
dis_phe_pd['disease'] = dis_loc
dis_phe_pd['phenotype'] = phe_loc
dis_phe_pd['annotator'] = annotator_names

sns.set(style="whitegrid")

dis_phe_pd = pd.melt(dis_phe_pd, "annotator", var_name="measurement")

dis_phe_pd

f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=dis_phe_pd, dodge=0, join=False,
              markers=["<", ">"], scale=1.25, ci=None, palette=sns.xkcd_palette(['green', 'red']))

#ax.set(xticks=[-3.0, -2.5, -2.0, -1.5, -1.0, -0.5, 0.0, 0.5])
#ax.set(xticks=np.arange(np.floor(theta_min), np.ceil(theta_max), 0.5))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

dis_inverses = 1/(xda - xdr)
print(dis_inverses)
# Out:
# [-1.38740398 -0.50669666 -1.43677386 -0.81082158 -2.23021635]

# %%
dis_phe_pd = pd.DataFrame()
dis_phe_pd['disease'] = dis_loc
dis_phe_pd['phenotype'] = phe_loc
dis_phe_pd['annotator'] = annotator_names

sns.set(style="whitegrid")

dis_phe_pd = pd.melt(dis_phe_pd, "annotator", var_name="measurement")

#print(dis_phe_pd)

f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=dis_phe_pd, dodge=0, join=False,
              markers=["<", ">"], scale=1.25, ci=None, palette=sns.xkcd_palette(['green', 'red']))

i = 0
for annotator in annotator_names:
    #annotator = 'Annotator{}'.format(i+1)
    dis = dis_phe_pd[(dis_phe_pd['annotator'] == annotator) & (dis_phe_pd['measurement'] == 'disease')]['value']
    
    phe = dis_phe_pd[(dis_phe_pd['annotator'] == annotator) & (dis_phe_pd['measurement'] == 'phenotype')]['value']
    
    plt.plot([-2, dis.sum()], [i-0.15, i-0.15], sns.xkcd_rgb["green"], lw=2, linestyle=':')
    plt.plot([phe.sum(), 2], [i+0.15, i+0.15], sns.xkcd_rgb["red"], lw=2, linestyle=':')
    if phe.sum() < dis.sum():
        plt.plot([phe.sum(), dis.sum()], [i, i], sns.xkcd_rgb["blue"], lw=2, linestyle=':')
    i += 1

#ax.set(xticks=[-3.0, -2.5, -2.0, -1.5, -1.0, -0.5, 0.0, 0.5])
ax.set(xticks=np.arange(theta_min, theta_max))
ax.set_xlabel('Estimated annotator position on the spectrum')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
dis_inverses = (xdr-xda)

dis_inverses_pd = pd.DataFrame()
dis_inverses_pd['error_bar'] = dis_inverses
dis_inverses_pd['annotator'] = annotator_names

ax = sns.barplot(x="annotator", y="error_bar", data=dis_inverses_pd, color="green")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_ylabel('Position stability estimate for disease')
# Out:
# Text(0,0.5,'Position stability estimate for disease')

# %%
phe_inverses = (xpa - xpr)

phe_inverses_pd = pd.DataFrame()
phe_inverses_pd['error_bar'] = phe_inverses
phe_inverses_pd['annotator'] = annotator_names

ax = sns.barplot(x="annotator", y="error_bar", data=phe_inverses_pd, color="red")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

ax.set_ylabel('Position stability estimate for phenotype')
# Out:
# Text(0,0.5,'Position stability estimate for phenotype')

# %%
def plot_theta_tokens(pos_annos):
    pos_theta = pos[['Token', 'theta']]
    pos_theta['zeros'] = 0
    ax = sns.scatterplot(x="theta", y="zeros", data=pos_theta)

# %%
new_pos = pos[(pos['Token'] == 'bloatedness') | (pos['Token'] == 'seizure') | (pos['Token'] == 'infection') | (pos['Token'] == 'arthritis') | (pos['Token'] == 'hypertension') | (pos['Token'] == 'anemia') | (pos['Token'] == 'myelomatosis')].drop_duplicates(['Token'])
new_pos.sort_values('theta', inplace=True)
labels = ['Phenotype', 'Phenotype', 'Both', 'Both', 'Disease', 'Disease', 'Disease']
labels.reverse()
new_pos['Majority Labels'] = labels

new_pos.reset_index()
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

palette={'Disease':'green', 'Phenotype':'red', 'Both':'blue'}
ax = sns.scatterplot(x="theta", y="zeros", data=new_pos, hue="Majority Labels", \
                     palette=palette) #, \
                     #hue_order=['Disease', 'Both', 'Phenotype'])

ax.get_yaxis().set_visible(False)

mult = 1
pick = {'Disease':'green', 'Phenotype':'red', 'Both':'blue'}
for index, row in new_pos.iterrows():
    color = pick[row['Majority Labels']]
    ax.text(row['theta']-0.1, 0.00007*mult, row['Token'], bbox = dict(facecolor=color, alpha=0.5), fontsize=14)
    mult *= -1
    
ax.arrow(-2.6, 0, 7.1, 0, head_width=0.00006, head_length=0.00002, width=0.000002, fc='brown', ec='brown') 
ax.set_xlabel('Disease-Phenotype spectrum')
# Out:
# Text(0.5,0,'Disease-Phenotype spectrum')

# %%
def count_relevant_stats(relevant_annotations, annotator, label):
    return relevant_annotations[relevant_annotations[annotator] == label][annotator].count()

# %%
def get_relevant_stats(relevant_annotations, annotator):
    print 'Statistics for {}'.format(annotator)
    total = float(len(relevant_annotations))
    print 'Percentage of Disease labels: {}'.format(count_relevant_stats(relevant_annotations, annotator, 'Disease')/total)
    print 'Percentage of Phenotype labels: {}'.format(count_relevant_stats(relevant_annotations, annotator, 'Phenotype')/total)
    print 'Percentage of both labels: {}'.format(count_relevant_stats(relevant_annotations, annotator, 'Both')/total)

# %%
for annotator in annotator_names:
    get_relevant_stats(relevant_annotations, annotator)
    print
# Out:
# Statistics for m2c1
# Percentage of Disease labels: 0.602216748768
# Percentage of Phenotype labels: 0.15763546798
# Percentage of both labels: 0.147783251232
#
# Statistics for m2c2
# Percentage of Disease labels: 0.618226600985
# Percentage of Phenotype labels: 0.230295566502
# Percentage of both labels: 0.0566502463054
#
# Statistics for m2c3
# Percentage of Disease labels: 0.465517241379
# Percentage of Phenotype labels: 0.18842364532
# Percentage of both labels: 0.177339901478
#
# Statistics for m2c5
# Percentage of Disease labels: 0.34236453202
# Percentage of Phenotype labels: 0.294334975369
# Percentage of both labels: 0.221674876847
#
# Statistics for m2c6_2nd
# Percentage of Disease labels: 0.817733990148
# Percentage of Phenotype labels: 0.128078817734
# Percentage of both labels: 0.0344827586207

# %%
dis_pd = pd.DataFrame()
dis_pd['Accept as disease'] = xda[1:2]
dis_pd['Reject as disease'] = xdr[1:2]
dis_pd['annotator'] = ['m2c2']

phe_pd = pd.DataFrame()
phe_pd['Accept as phenotype'] = xpa[1:2]
phe_pd['Reject as phenotype'] = xpr[1:2]
phe_pd['annotator'] = ['m2c3']
#'''

sns.set(style="whitegrid")

dis_pd = pd.melt(dis_pd, "annotator", var_name="measurement")
phe_pd = pd.melt(phe_pd, "annotator", var_name="measurement")

#print(dis_pd)
#print
#print(phe_pd)

f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=dis_pd, dodge=0, join=False,
              markers="o", scale=1.25, ci=None, palette=sns.xkcd_palette(["green", "light green"]))

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=phe_pd, dodge=0, join=False,
              markers="x", scale=1.25, ci=None, palette=sns.xkcd_palette(["dark red", "light red"]))

#ax.set_title('Annotator positions')
ax.set_xlabel('Annotator position on the spectrum')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.arrow(-2.6, 0.002, 8.1, 0.002, fc='brown', ec='brown')

# %%
dis_phe_pd = pd.DataFrame()
dis_phe_pd['disease'] = dis_loc[1:2]
dis_phe_pd['phenotype'] = phe_loc[1:2]
dis_phe_pd['annotator'] = ['m2c2']

sns.set(style="whitegrid")

dis_phe_pd = pd.melt(dis_phe_pd, "annotator", var_name="measurement")

#print(dis_phe_pd)

f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=dis_phe_pd, dodge=0, join=False,
              markers=["<", ">"], scale=1.25, ci=None, palette=sns.xkcd_palette(['green', 'red']))

#ax.set(xticks=[-3.0, -2.5, -2.0, -1.5, -1.0, -0.5, 0.0, 0.5])
ax.set(xticks=np.arange(np.floor(theta_min), np.ceil(theta_max)))
ax.set_xlabel('Estimated annotator position on the spectrum')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.arrow(-3.1, 0.002, 4.1, 0.002, fc='brown', ec='brown')

# %%
dis_pd = pd.DataFrame()
dis_pd['Accept as disease'] = xda[2:3]
dis_pd['Reject as disease'] = xdr[2:3]
dis_pd['annotator'] = ['m2c3']

phe_pd = pd.DataFrame()
phe_pd['Accept as phenotype'] = xpa[2:3]
phe_pd['Reject as phenotype'] = xpr[2:3]
phe_pd['annotator'] = ['m2c3']
#'''

sns.set(style="whitegrid")

dis_pd = pd.melt(dis_pd, "annotator", var_name="measurement")
phe_pd = pd.melt(phe_pd, "annotator", var_name="measurement")

#print(dis_pd)
#print
#print(phe_pd)

f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=dis_pd, dodge=0, join=False,
              markers="o", scale=1.25, ci=None, palette=sns.xkcd_palette(["green", "light green"]))

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=phe_pd, dodge=0, join=False,
              markers="x", scale=1.25, ci=None, palette=sns.xkcd_palette(["dark red", "light red"]))

#ax.set_title('Annotator positions')
ax.set_xlabel('Annotator position on the spectrum')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.arrow(-4.6, 0.002, 12.1, 0.002, fc='brown', ec='brown')

# %%
dis_phe_pd = pd.DataFrame()
dis_phe_pd['disease'] = dis_loc[2:3]
dis_phe_pd['phenotype'] = phe_loc[2:3]
dis_phe_pd['annotator'] = ['m2c3']

sns.set(style="whitegrid")

dis_phe_pd = pd.melt(dis_phe_pd, "annotator", var_name="measurement")

#print(dis_phe_pd)

f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

sns.pointplot(x="value", y="annotator", hue="measurement",
              data=dis_phe_pd, dodge=0, join=False,
              markers=["<", ">"], scale=1.25, ci=None, palette=sns.xkcd_palette(['green', 'red']))

#ax.set(xticks=[-3.0, -2.5, -2.0, -1.5, -1.0, -0.5, 0.0, 0.5])
ax.set(xticks=np.arange(np.floor(theta_min), np.ceil(theta_max)))
ax.set_xlabel('Estimated annotator position on the spectrum')

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.arrow(-12.1, 0.002, 20.1, 0.002, fc='brown', ec='brown')

# %%
pos
# Out:
#                    Token       m2c1       m2c2       m2c3       m2c5  \
# 0             Haematuria  Phenotype  Phenotype       Both  Phenotype
# 1              abdominal    Disease    Disease    Disease       Both
# 2                 aortic    Disease    Disease    Disease       Both
# 3               aneurysm    Disease    Disease    Disease       Both
# 4             Haematuria  Phenotype  Phenotype       Both  Phenotype
# 5                   left  Phenotype  Phenotype       None       None
# 6                   loin  Phenotype  Phenotype       None  Phenotype
# 7                   pain  Phenotype  Phenotype       Both  Phenotype
# 8              abdominal    Disease    Disease    Disease       Both
# 9                 aortic    Disease    Disease    Disease       Both
# 10              aneurysm       None    Disease    Disease       Both
# 11                 aorto       None    Disease    Disease    Disease
# 12                     -       None    Disease    Disease    Disease
# 13                  left       None    Disease    Disease    Disease
# 14                 renal       None    Disease    Disease    Disease
# 15                  vein       None    Disease    Disease    Disease
# 16               fistula       None       Both       Both    Disease
# 17              aneurysm       None       Both    Disease       Both
# 18            Acanthosis    Disease       Both       Both       Both
# 19             nigricans    Disease       Both       Both       Both
# 20            Acanthosis    Disease       Both       Both       Both
# 21             nigricans    Disease       Both       Both       Both
# 22        hyperpigmented  Phenotype       None  Phenotype       None
# 23                  skin  Phenotype       None  Phenotype       None
# 24             endocrine    Disease       None       None       Both
# 25             disorders    Disease       None       None       Both
# 26          malignancies    Disease       None       None       Both
# 27             fractured    Disease  Phenotype  Phenotype    Disease
# 28             phalanges    Disease  Phenotype  Phenotype    Disease
# 29             fractured    Disease  Phenotype  Phenotype    Disease
# ..                   ...        ...        ...        ...        ...
# 782            tenseness  Phenotype       None  Phenotype  Phenotype
# 783  pseudohallucination    Disease       None       None  Phenotype
# 784                focal       Both       None       Both  Phenotype
# 785         neurological       Both  Phenotype       Both  Phenotype
# 786              deficit       Both  Phenotype       Both  Phenotype
# 787          sarcoidosis    Disease    Disease    Disease       Both
# 788          Sarcoidosis    Disease    Disease    Disease       Both
# 789               stroke    Disease    Disease    Disease  Phenotype
# 790                focal       Both  Phenotype       Both  Phenotype
# 791         neurological       Both  Phenotype       Both  Phenotype
# 792              deficit       Both  Phenotype       Both  Phenotype
# 793                focal       Both  Phenotype       Both  Phenotype
# 794         neurological       Both  Phenotype       Both  Phenotype
# 795              deficit       Both  Phenotype       Both  Phenotype
# 796             episodic  Phenotype  Phenotype       None  Phenotype
# 797                  non  Phenotype  Phenotype       None  Phenotype
# 798                    -  Phenotype  Phenotype       None  Phenotype
# 799               fluent  Phenotype  Phenotype       None  Phenotype
# 800            dysphasia       Both  Phenotype       Both  Phenotype
# 801              seizure    Disease       Both       Both  Phenotype
# 802     neurosarcoidosis    Disease    Disease    Disease       Both
# 803            ischaemic       Both       Both  Phenotype  Phenotype
# 804         neurological       Both       Both  Phenotype  Phenotype
# 805              deficit       Both       Both  Phenotype  Phenotype
# 806              fatigue  Phenotype       None  Phenotype  Phenotype
# 807           insulinoma       Both    Disease       Both  Phenotype
# 808            posterior    Disease    Disease       None    Disease
# 809             urethral    Disease    Disease       Both    Disease
# 810           strictures    Disease    Disease       Both    Disease
# 811                   MS    Disease    Disease    Disease    Disease
#
#       m2c6_2nd     theta  zeros
# 0         Both  1.201779      0
# 1      Disease -0.482135      0
# 2      Disease -0.454420      0
# 3      Disease -0.429371      0
# 4         Both  1.219414      0
# 5    Phenotype  1.857872      0
# 6    Phenotype  1.922677      0
# 7    Phenotype  1.396721      0
# 8      Disease -0.443896      0
# 9      Disease -0.434968      0
# 10     Disease -0.436164      0
# 11     Disease -1.030184      0
# 12     Disease -1.005206      0
# 13     Disease -1.148942      0
# 14     Disease -1.172711      0
# 15     Disease -1.068951      0
# 16     Disease  0.118213      0
# 17     Disease  0.117341      0
# 18     Disease  0.178343      0
# 19     Disease  0.176246      0
# 20     Disease  0.200392      0
# 21     Disease  0.198073      0
# 22   Phenotype  1.989046      0
# 23   Phenotype  1.905903      0
# 24     Disease -0.291159      0
# 25     Disease -0.291181      0
# 26     Disease -0.320879      0
# 27     Disease  0.450410      0
# 28     Disease  0.457387      0
# 29     Disease  0.452268      0
# ..         ...       ...    ...
# 782  Phenotype  1.921041      0
# 783  Phenotype  0.790939      0
# 784    Disease  0.646008      0
# 785    Disease  0.834107      0
# 786    Disease  0.839292      0
# 787    Disease -0.454409      0
# 788    Disease -0.459153      0
# 789    Disease -0.022613      0
# 790    Disease  0.832939      0
# 791    Disease  0.826986      0
# 792    Disease  0.858268      0
# 793    Disease  0.860384      0
# 794    Disease  0.831964      0
# 795    Disease  0.810552      0
# 796  Phenotype  1.865329      0
# 797  Phenotype  1.838620      0
# 798  Phenotype  1.975713      0
# 799  Phenotype  1.781728      0
# 800    Disease  0.854583      0
# 801    Disease  0.364885      0
# 802    Disease -0.497607      0
# 803    Disease  0.588642      0
# 804    Disease  0.584779      0
# 805    Disease  0.582968      0
# 806       None  1.596515      0
# 807    Disease  0.284534      0
# 808    Disease -1.055087      0
# 809    Disease -0.392246      0
# 810    Disease -0.398161      0
# 811    Disease -1.093425      0
#
# [812 rows x 8 columns]

# %%
(theta_min + theta_max)/2
# Out:
# 0.3438812238943806

# %%
r = mixed_annotations[mixed_annotations[mixed_annotations[annotator_names] != 'None'].count(axis=1) == 2]
r.index
# Out:
# Int64Index([  26,   27,   28,   29,   30,   31,   32,   68,   69,   70,
#             ...
#             6811, 6812, 6830, 6839, 6840, 6842, 6857, 6858, 6859, 7068],
#            dtype='int64', length=215)

# %%
def get_majority_not_relevant_rows(annotations):
    majority = np.ceil(len(annotator_names)/2.0)
    relevant = annotations[annotations[annotations[annotator_names] != 'None'].count(axis=1) < majority]
    return relevant

nrelevant_annotations = get_relevant_rows(mixed_annotations)
majority_not_rel = get_majority_not_relevant_rows(mixed_annotations)
npos = pd.DataFrame()
npos = pd.concat([npos, mixed_annotations[['Token']]])
npos['theta'] = None
npos.loc[nrelevant_annotations.index, 'theta'] = avg_values['theta']
#npos.loc[majority_not_rel.index, 'theta'] = None
npos
# Out:
#               Token     theta
# 0        Haematuria   1.20178
# 1               and      None
# 2         abdominal -0.482135
# 3            aortic  -0.45442
# 4          aneurysm -0.429371
# 5                 .      None
# 6        Haematuria   1.21941
# 7               and      None
# 8              left   1.85787
# 9              loin   1.92268
# 10             pain   1.39672
# 11               in      None
# 12                a      None
# 13          patient      None
# 14             with      None
# 15        abdominal -0.443896
# 16           aortic -0.434968
# 17         aneurysm -0.436164
# 18              and      None
# 19       associated      None
# 20             with      None
# 21              the      None
# 22     radiological      None
# 23          finding      None
# 24               of      None
# 25                a      None
# 26           poorly      None
# 27               or      None
# 28              non      None
# 29                -      None
# ...             ...       ...
# 7833              ,      None
# 7834              2      None
# 7835              -      None
# 7836  methylbutanal      None
# 7837              ,      None
# 7838              2      None
# 7839              -      None
# 7840         acetyl      None
# 7841              -      None
# 7842              1      None
# 7843              -      None
# 7844      pyrroline      None
# 7845              ,      None
# 7846              1      None
# 7847              -      None
# 7848          octen      None
# 7849              -      None
# 7850              3      None
# 7851              -      None
# 7852             ol      None
# 7853              ,      None
# 7854            and      None
# 7855              1      None
# 7856              -      None
# 7857          octen      None
# 7858              -      None
# 7859              3      None
# 7860              -      None
# 7861            one      None
# 7862              .      None
#
# [7863 rows x 2 columns]

# %%
def get_new_labels(pos_annos, theta_thresh):
    new_labels = pd.DataFrame()
    new_labels = pd.concat([new_labels, pos_annos['Token']])
    new_labels['col1'] = '?'
    new_labels['col2'] = '?'
    new_labels['Label'] = 'O'
    new_labels.loc[(pos_annos['theta'] > theta_thresh), 'Label'] = 'I-phenotype'
    return new_labels

# %%
def save_new_labels(pos_annos, theta_thresh, prefix):
    new_labels = get_new_labels(pos_annos, theta_thresh)
    new_file = os.path.join(read_datasets.get_dataset_folder(), CF.get('m2c_new_labels', 'path'), '{}_m2c_new_labels_{}.txt'.format(prefix, theta_thresh))
    new_labels.to_csv(new_file, sep=' ', index=False, header=False)
    new_labels[new_labels['Label'] == 'I-phenotype'].count()

# %%
save_new_labels(npos, (theta_min + theta_max)/2, 'no_ner_no_1stpass_midpoint_glad') #midpoint of all theta values.

# %%
print theta_min, theta_max
nl = get_new_labels(npos, (theta_min + theta_max)/2)
print nl[nl['Label'] == 'I-phenotype'].count()[0]
#print nl.count()
# Out:
# -1.3802972572922199 2.068059705080981
# 274

# %%
npos.to_csv('theta_values.txt', index=False)

# %%
#zz = pd.read_csv('theta_values_with_expert.txt')

# %%
def get_vote_pheno_labels(phenotype_all_annos, minimum_vote):
    pheno_vote = pd.DataFrame()
    pheno_vote = pd.concat([pheno_vote, phenotype_all_annos['Token']])
    pheno_vote['col1'] = '?'
    pheno_vote['col2'] = '?'
    pheno_vote['Label'] = 'O'
    
    pheno_vote.loc[phenotype_all_annos[phenotype_all_annos[annotator_names].sum(axis=1) >= minimum_vote].index, 'Label'] = 'I-phenotype'
    return pheno_vote

# %%
phenotype_all_annos = read_phenotype_annotations()
if include_NER:
    phenotype_all_annos = pd.concat([phenotype_all_annos, expert_phenotype_annotations['NER_expert']], axis=1)
maj = get_vote_pheno_labels(phenotype_all_annos, 3)

# %%
maj[maj['Label'] == 'I-phenotype'].count()
# Out:
# 0        232
# col1     232
# col2     232
# Label    232
# dtype: int64

# %%
maj.count()
# Out:
# 0        7863
# col1     7863
# col2     7863
# Label    7863
# dtype: int64

# %%
new_file = os.path.join(read_datasets.get_dataset_folder(), CF.get('m2c_new_labels', 'path'), 'm2c_new_labels_majority.txt')
maj.to_csv(new_file, sep=' ', index=False, header=False)

# %%
for i in np.linspace(theta_min, theta_max, 6):
    #print i
    z = get_new_labels(npos, i)
    count = z[z['Label'] == 'I-phenotype'][0].count()
    if count > 0:
        print i, count
# Out:
# -1.3802972572922199 811
# -0.6906258648175796 574
# -0.0009544723429393276 373
# 0.6887169201317012 185
# 1.3783883126063412 81

# %%
#new_labels.save_new_labels(npos, 1.3783883126063412, 'glad_combined')

# %% [raw]
# new_labels.save_new_labels(npos, 1.3783883126063412, 'glad_combined')

# %%
phe_loc
# Out:
# array([ 0.45307719,  0.35533866,  0.09670889, -0.39938302,  1.23528939])

# %%
hpo = read_datasets.load_dataset(dataset='phenotype', mode='test')
len(hpo)
# Out:
# 7800

# %%
hpo[hpo[3] == 'I-phenotype'].loc[:].count()
len(hpo)
# Out:
# 7800

# %%
zz = pd.read_csv('theta_values.txt')

# %%
from scripps.utils import new_labels
#zz = pd.read_csv('theta_values.txt')
zz = npos
theta_min = zz['theta'].min()
theta_max = zz['theta'].max()
for i in np.linspace(theta_min, theta_max, 6):
    #nl = new_labels.get_new_labels(zz, i)
    #count = z[z['Label'] == 'I-phenotype'][0].count()
    new_labels.save_new_labels(zz, i, 'glad_combined')
    #print nl[nl['Label'] == 'I-phenotype'].count()[0]
# Out:
# Saved at ../dataset/M2C_new_labels/glad_combined_m2c_new_labels_-1.38029725729.txt
# Number of new phenotype labels: 811
# Saved at ../dataset/M2C_new_labels/glad_combined_m2c_new_labels_-0.690625864818.txt
# Number of new phenotype labels: 574
# Saved at ../dataset/M2C_new_labels/glad_combined_m2c_new_labels_-0.000954472342939.txt
# Number of new phenotype labels: 373
# Saved at ../dataset/M2C_new_labels/glad_combined_m2c_new_labels_0.688716920132.txt
# Number of new phenotype labels: 185
# Saved at ../dataset/M2C_new_labels/glad_combined_m2c_new_labels_1.37838831261.txt
# Number of new phenotype labels: 81
# Saved at ../dataset/M2C_new_labels/glad_combined_m2c_new_labels_2.06805970508.txt
# Number of new phenotype labels: 0

# %%
theta_max
# Out:
# 2.068059705080981
